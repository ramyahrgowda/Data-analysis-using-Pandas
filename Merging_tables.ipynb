# %%
import pandas as pd
import numpy as np

# %%
df_churn_raw = pd.read_csv('Churn_in_telecom_dataset.csv')

# %%
df_churn_raw.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# ### concat, merge,

# %%
df_churn_raw.shape
# Out:
# (3333, 21)

# %%
df_churn_raw.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
#Dividing data into 2 dataframes
df_churn_1 = df_churn_raw.iloc[0:1500,:]
df_churn_2 = df_churn_raw.iloc[1500:,:]

# %%
df_churn_1.shape
# Out:
# (1500, 21)

# %%
df_churn_2.shape
# Out:
# (1833, 21)

# %%
#splitting data column wise
df_churn_day = df_churn_raw[['phone number','total day minutes', 'total day calls', 'total day charge']]
df_churn_eve = df_churn_raw[['phone number','total eve minutes', 'total eve calls', 'total eve charge']]
df_churn_night = df_churn_raw[['total night minutes', 'total night calls', 'total night charge']]

# %% [markdown]
# #### Concat

# %%
#combining data split row-wise
pd.concat([df_churn_1,df_churn_2])
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# 5       AL             118        510     391-8027                yes
# 6       MA             121        510     355-9993                 no
# 7       MO             147        415     329-9001                yes
# 8       LA             117        408     335-4719                 no
# 9       WV             141        415     330-8173                yes
# 10      IN              65        415     329-6603                 no
# 11      RI              74        415     344-9403                 no
# ...

# %%
#combining data split row-wise
df_churn_1.append(df_churn_2)
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# 5       AL             118        510     391-8027                yes
# 6       MA             121        510     355-9993                 no
# 7       MO             147        415     329-9001                yes
# 8       LA             117        408     335-4719                 no
# 9       WV             141        415     330-8173                yes
# 10      IN              65        415     329-6603                 no
# 11      RI              74        415     344-9403                 no
# ...

# %% [markdown]
# #### merge

# %%
#merging data - left join on column 'phone number'
pd.merge(left=df_churn_day,right=df_churn_eve,how='left',left_on='phone number',right_on='phone number')
# Out:
#      phone number  total day minutes  total day calls  total day charge  \
# 0        382-4657              265.1              110             45.07
# 1        371-7191              161.6              123             27.47
# 2        358-1921              243.4              114             41.38
# 3        375-9999              299.4               71             50.90
# 4        330-6626              166.7              113             28.34
# 5        391-8027              223.4               98             37.98
# 6        355-9993              218.2               88             37.09
# 7        329-9001              157.0               79             26.69
# 8        335-4719              184.5               97             31.37
# 9        330-8173              258.6               84             43.96
# 10       329-6603              129.1              137             21.95
# 11       344-9403              187.7              127             31.91
# ...

# %%
#concat can also be used if index are matching
pd.concat([df_churn_day,df_churn_eve,df_churn_night],axis=1)
# Out:
#      phone number  total day minutes  total day calls  total day charge  \
# 0        382-4657              265.1              110             45.07
# 1        371-7191              161.6              123             27.47
# 2        358-1921              243.4              114             41.38
# 3        375-9999              299.4               71             50.90
# 4        330-6626              166.7              113             28.34
# 5        391-8027              223.4               98             37.98
# 6        355-9993              218.2               88             37.09
# 7        329-9001              157.0               79             26.69
# 8        335-4719              184.5               97             31.37
# 9        330-8173              258.6               84             43.96
# 10       329-6603              129.1              137             21.95
# 11       344-9403              187.7              127             31.91
# ...
